# %%
# %matplotlib inline 
from make_results_figure import make_group_plot


class args_list(object):
    pass

args = args_list()
args.directory = 'output'
args.prefix = 'qlearn_grid_24_nep_4347'
args.buckets = 10.0
args.figSizeX = 12
args.figSizeY = 5

make_group_plot(args)

# %%
# %matplotlib inline 
from make_results_figure import make_group_plot


class args_list(object):
    pass

args = args_list()
args.directory = 'output'
args.prefix = 'sarsa_nep_4347'
args.buckets = 10.0
args.figSizeX = 12
args.figSizeY = 5

make_group_plot(args)
