# %%
# %matplotlib inline 
from make_results_figure import make_group_plot


class args_list(object):
    pass

args = args_list()
args.directory = 'output'
args.prefix = 'qlearn'
args.buckets = 100.0
args.figSizeX = 12
args.figSizeY = 5

make_group_plot(args)

# %%
args = args_list()
args.directory = 'output'
args.prefix = 'sarsa'
args.buckets = 100.0
args.figSizeX = 12
args.figSizeY = 5

make_group_plot(args)
