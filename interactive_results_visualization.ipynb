# %%
# %matplotlib inline 
import seaborn as sns
import make_results_figure
from make_results_figure import *


class args_list(object):
    pass

args = args_list()
args.directory = 'output'
args.prefix = 'qlearn'
args.buckets = 100.0
args.figSizeX = 12
args.figSizeY = 5

q_learn_results = make_group_plot(args)
# Out:
# /Users/korymathewson/miniconda2/lib/python2.7/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
args.prefix = 'sarsa'
sarsa_results = make_group_plot(args)

# %%
args.prefix = 'random'
random_results = make_group_plot(args)

# %%
res = [q_learn_results[:2,:], sarsa_results[:2,:], random_results[:2,:]]
keys = ['q_learn', 'sarsa', 'random']
make_comparison_plot(args, res, keys)
